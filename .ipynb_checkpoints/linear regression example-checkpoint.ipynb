# %%
from __future__ import absolute_import, division, print_function
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
rng = np.random

import tensorflow_datasets as tfds
from tensorflow import keras

# %%
## Import libs

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
import pandas as pd

# %%
mnist = keras.datasets.fashion_mnist

# %%
type(mnist)
# Out:
# module

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
np.max(X_train)
# Out:
# 255

# %%
np.mean(X_train)
# Out:
# 72.94035223214286

# %%
class_names = ['top', 'trouser', 'pullover', 'dress', 'coat', 'scandal', 'shirt', 'sneaker', 'bag', 'ankle_boot']

# %% [markdown]
# # data exploration

# %%
plt.figure()
plt.imshow(X_train[100])
plt.colorbar()

# %%
X_train=X_train / 255.0
X_test=X_test / 255.0

# %% [markdown]
# # Build the model with TF 2.0

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model compilation
# + Loss function
# + Optimizer
# + Metrics

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5016 - accuracy: 0.8236
# Epoch 2/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.3770 - accuracy: 0.8644
# Epoch 3/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.3396 - accuracy: 0.8767
# Epoch 4/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.3146 - accuracy: 0.8838
# Epoch 5/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2961 - accuracy: 0.8908
# Epoch 6/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2826 - accuracy: 0.8952
# Epoch 7/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.2678 - accuracy: 0.9006
# Epoch 8/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2579 - accuracy: 0.9036
# Epoch 9/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2482 - accuracy: 0.9066
# Epoch 10/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2417 - accuracy: 0.9093

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.881

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict_classes(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.881
